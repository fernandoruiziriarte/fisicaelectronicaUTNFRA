# %%
import matplotlib.pyplot as plt
import numpy as np

# Data experimental
x = [0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3]
y = [2.55, 0.65, -2.35, -6.2, -7.25, -10, -12.15, -15, -18.05, -18.7, -22, -24.4]

# Encuentra la pendiente y la intersección de la mejor línea de ajuste
pend, yint = np.polyfit(x, y, 1) # 1, porque es lineal

# Crea los valores de la recta
abline_values = [pend * i + yint for i in x]

# Imprime la recta de ajuste sobre los valores medidos
plt.plot(x, y, 'o', color = 'red')
plt.plot(x, abline_values, '--')
plt.show()



def LineFit(x, y):
 # Devuelve la pendiente y la ordenada al origen del ajuste lineal al dataset
    x_prom = x.mean()
    pend = (y * (x - x_prom)).sum() / (x * (x - x_prom)).sum()
    yint = y.mean() - pend * x_prom
    return pend, yint

def abline(pend, yint, x, y):
    # Imprime una línea en base a una pendiente y una ordenada al origen
    vals = yint + pend * x_vals
    plt.plot(x, y, 'o', color = 'red')
    plt.plot(x, y_vals, '—')
